# %%
import pandas

# %% [markdown]
# # user-defined variables

# %%
expression_file = '/home/adrian/databases/gtex/zscore.tsv'
sky_blue_transcripts_file = '/home/adrian/databases/gtex/skyblue_transcripts.tsv'
gold_transcripts_file = '/home/adrian/databases/gtex/gold_transcripts.tsv'
output_dir = '/home/adrian/scratch/'

# %% [markdown]
# # read data

# %%
# %%time
zscore_df = pandas.read_csv(expression_file, index_col=0, sep='\t')
print(zscore_df.shape)
zscore_df.head()
# Out:
# (46490, 4385)
# CPU times: user 31.9 s, sys: 1.1 s, total: 33 s
# Wall time: 33 s
#                    GTEX-S4Q7-0003-SM-3NM8M  GTEX-QV31-1626-SM-2S1QC  \
# sample
# ENST00000625998.2                 0.201517                 0.036483
# ENST00000583693.5                -0.157536                -0.387785
# ENST00000012134.6                -1.858374                -0.230357
# ENST00000403263.5                 1.824639                 0.803760
# ENST00000449352.6                -0.714858                 0.391161
#
#                    GTEX-13OW5-0626-SM-5J2N2  GTEX-ZPCL-0126-SM-4WWC8  \
# sample
# ENST00000625998.2                 -2.678424                -1.913425
# ENST00000583693.5                  0.348795                 0.398806
# ENST00000012134.6                 -1.101552                -1.678630
# ENST00000403263.5                 -0.939061                -0.804629
# ENST00000449352.6                 -0.649496                -0.251540
#
# ...

# %%
sky_blue_transcripts = pandas.read_csv(sky_blue_transcripts_file, sep='\t')
print(sky_blue_transcripts.shape)

gold_transcripts = pandas.read_csv(gold_transcripts_file, sep='\t')
print(gold_transcripts.shape)
# Out:
# (3098, 1)
# (1754, 1)

# %%
sky_blue_transcripts
# Out:
#               ENSEMBL
# 0     ENSG00000169062
# 1     ENSG00000152795
# 2     ENSG00000266412
# 3     ENSG00000114850
# 4     ENSG00000003056
# ...               ...
# 3093  ENSG00000132463
# 3094  ENSG00000156253
# 3095  ENSG00000101040
# 3096  ENSG00000276016
# 3097  ENSG00000074800
#
# [3098 rows x 1 columns]

# %%
cluster one block, cluster the other one, and then cluster the columns

# %%
pep=sky_blue_transcripts['ENSEMBL'].to_list()

# %%
zscore_df
# Out:
#                    GTEX-S4Q7-0003-SM-3NM8M  GTEX-QV31-1626-SM-2S1QC  \
# sample
# ENST00000625998.2                 0.201517                 0.036483
# ENST00000583693.5                -0.157536                -0.387785
# ENST00000012134.6                -1.858374                -0.230357
# ENST00000403263.5                 1.824639                 0.803760
# ENST00000449352.6                -0.714858                 0.391161
# ...                                    ...                      ...
# ENST00000470412.5                -0.343926                -0.700203
# ENST00000469534.1                -0.658335                -0.508709
# ENST00000507412.1                 1.256783                 1.699418
# ENST00000568351.1                -1.172953                 0.246373
# ENST00000491408.1                -0.713929                 0.883018
#
#                    GTEX-13OW5-0626-SM-5J2N2  GTEX-ZPCL-0126-SM-4WWC8  \
# sample
# ...
